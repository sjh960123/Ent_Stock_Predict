# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jyp_r = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/주가/데이터 전처리본/JYP_ent.csv')
sm_r = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/주가/데이터 전처리본/SM_ent.csv')
yg_r = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/주가/데이터 전처리본/YG_ent.csv')

jyp_s = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/주가/데이터 전처리본/JYP_ent', index_col = 0)
sm_s = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/주가/데이터 전처리본/SM_ent', index_col = 0)
yg_s = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/주가/데이터 전처리본/YG_ent', index_col = 0)

kd = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/경제지표/경제지표_코스닥_전처리/코스닥.csv', index_col = 0)
ir = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/경제지표/경제지표_코스닥_전처리/금리.csv', index_col = 0)
gdp = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/경제지표/경제지표_코스닥_전처리/GDP.csv')
er = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝투/some file/data/경제지표/경제지표_코스닥_전처리/환율.csv')

# %%
import datetime

# %%
sm_s.index = pd.to_datetime(sm_s.index)
jyp_s.index = pd.to_datetime(jyp_s.index)
yg_s.index = pd.to_datetime(yg_s.index)

# %%
sm_s.sort_index(inplace=True)
jyp_s.sort_index(inplace=True)
yg_s.sort_index(inplace=True)
kd.sort_index(inplace=True)

# %%
plt.figure(figsize = (30,10))

plt.subplot(3,2,1)
sns.lineplot(data=sm_s,x=sm_s.index,y='종가')
plt.subplot(3,2,2)
sns.lineplot(data=kd,x=kd.index,y='종가')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize = (30,10))

plt.subplot(3,2,1)
sns.lineplot(data=yg_s,x=yg_s.index,y='종가')
plt.subplot(3,2,2)
sns.lineplot(data=kd,x=kd.index,y='종가')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize = (30,10))

plt.subplot(3,2,1)
sns.lineplot(data=jyp_s,x=jyp_s.index,y='종가')
plt.subplot(3,2,2)
sns.lineplot(data=kd,x=kd.index,y='종가')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
